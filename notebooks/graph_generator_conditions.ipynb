# %%
import ast
import re
import numpy as np
import pandas as pd
from rdkit import Chem
import tensorflow as tf
from rdkit.Chem import AllChem
import matplotlib.pyplot as plt
import tensorflow.keras as keras
from tensorflow.keras import layers, models
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
#use in get_data.py
def normalize_graph_features(x):
    x = re.sub(r'(?<=[0-9])\s+(?=[0-9])', ',', x)
    x = re.sub(r'\]\s+\[', '],[', x)
    return x

# %%
def preprocess_node_features(node_features_list, valid_atom_types, num_nodes):
    num_features = len(valid_atom_types)
    one_hot_features = np.zeros((num_nodes, num_features))

    atom_type_to_index = {atom: idx for idx, atom in enumerate(valid_atom_types)}

    for i, atom in enumerate(node_features_list):
        if atom[0] in atom_type_to_index:
            one_hot_features[i, atom_type_to_index[atom[0]]] = 1

    return one_hot_features

# %%
def pad_adj_matrix(matrix, max_size):
    padded_matrix = np.zeros((max_size, max_size))
    n, m = matrix.shape
    padded_matrix[:n, :m] = matrix
    return padded_matrix

# %%
def create_dataset(adj_matrices, one_hot_node_features, batch_size=32):
    dataset = tf.data.Dataset.from_tensor_slices((one_hot_node_features, adj_matrices))
    dataset = dataset.shuffle(buffer_size=len(one_hot_node_features)).batch(batch_size)
    return dataset

# %%
def pad_one_hot_features(features, max_size, num_features):
    padded_features = np.zeros((max_size, num_features))
    n, _ = features.shape
    padded_features[:n, :] = features
    return padded_features

# %%
qm9 = pd.read_csv("../Data/qm9.csv")
qm9.tail()
# Out:
#             mol_id               smiles        A        B        C      mu  \
# 133880  gdb_133881  C1C2C3C4C5OC14C5N23  3.59483  2.19899  1.90423  1.6637
# 133881  gdb_133882  C1N2C3C2C2C4OC12C34  3.65648  2.14237  1.90439  1.2976
# 133882  gdb_133883  C1N2C3C4C5C2C13CN45  3.67118  2.14314  1.89501  1.2480
# 133883  gdb_133884  C1N2C3C4C5CC13C2C45  3.52845  2.15131  1.86582  1.9576
# 133884  gdb_133885  C1N2C3C4C5OC13C2C45  3.64015  2.21764  1.93793  0.8626
#
#         alpha    homo    lumo     gap  ...        g298      cv      u0_atom  \
# 133880  69.37 -0.2254  0.0588  0.2842  ... -400.663098  23.658 -1603.983913
# 133881  69.52 -0.2393  0.0608  0.3002  ... -400.658942  23.697 -1601.376613
# 133882  73.60 -0.2233  0.0720  0.2953  ... -380.783148  23.972 -1667.045429
# 133883  77.40 -0.2122  0.0881  0.3003  ... -364.749650  24.796 -1794.600439
# 133884  69.48 -0.2316  0.0742  0.3058  ... -400.662186  23.434 -1603.471865
#
# ...

# %%
#use in get_data.py
qm9['adj_matrix'] = qm9["adj_matrix"].apply(normalize_graph_features)
qm9['node_features'] = qm9["node_features"].apply(normalize_graph_features)

# %%
#use in get_data.py
qm9['adj_matrix'] = qm9['adj_matrix'].apply(lambda x: np.array(ast.literal_eval(x)))
qm9['node_features'] = qm9['node_features'].apply(lambda x: ast.literal_eval(x))

# %%
valid_atom_types = [1, 6, 7, 8, 9]
num_features = len(valid_atom_types)

one_hot_node_features = [
    preprocess_node_features(nf, valid_atom_types, num_nodes)
    for nf, num_nodes in zip(qm9['node_features'], qm9['node_count'])
]

# %%
max_size = max(matrix.shape[0] for matrix in qm9['adj_matrix'])
qm9['adj_matrix'] = qm9['adj_matrix'].apply(lambda x: pad_adj_matrix(x, max_size))

# %%
one_hot_node_features = [
    pad_one_hot_features(features, max_size, num_features)
    for features in one_hot_node_features
]

# %%
adj_matrices = np.stack(qm9['adj_matrix'].values)
one_hot_node_features = np.stack(one_hot_node_features)

# %%
molecular_properties = qm9[["A", "B", "C", "mu", "alpha", "homo", "lumo", "gap", "g298", "cv", "u0_atom", "u298_atom", "h298_atom", "g298_atom"]].values
num_prop = molecular_properties.shape[1]

# %%
adj_matrices_small = adj_matrices[:1000]
one_hot_node_features_small = one_hot_node_features[:1000]
molecular_properties_small = molecular_properties[:1000]

# %%
def create_dataset(adj_matrices, node_features, molecular_properties, batch_size=32):
    dataset = tf.data.Dataset.from_tensor_slices((node_features, adj_matrices, molecular_properties))
    dataset = dataset.batch(batch_size).shuffle(1000)
    return dataset

# %%
dataset_small = create_dataset(adj_matrices_small, one_hot_node_features_small, molecular_properties_small, batch_size=32)
dataset = create_dataset(adj_matrices, one_hot_node_features, molecular_properties, batch_size=32)

# %%
"""class GraphGenerator(tf.keras.Model):
    def __init__(self, num_nodes, node_features, latent_dim, num_prop):
        super().__init__()
        self.num_nodes = num_nodes
        self.node_features = node_features
        self.latent_dim = latent_dim
        self.num_prop = num_prop

        self.mlp = models.Sequential([
            layers.Dense(128, input_shape=(self.latent_dim + self.num_prop,), activation="relu"),
            layers.Dense(256, activation="relu"),
            layers.Dense((self.num_nodes * self.num_nodes) + (self.num_nodes * self.node_features), activation="softmax")
        ])

        self.optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5)

    def call(self, z, properties):
        batch_size = tf.shape(z)[0]
        output = self.mlp(tf.concat([z, properties], axis=-1))  # Concatenate latent vector and properties

        adj_flat = output[:, :self.num_nodes * self.num_nodes]
        adj_flat = tf.nn.sigmoid(adj_flat)
        node_feature_flat = output[:, self.num_nodes * self.num_nodes:]

        adj = tf.reshape(adj_flat, (batch_size, self.num_nodes, self.num_nodes))
        adj = (adj + tf.transpose(adj, perm=[0, 2, 1])) / 2  # Symmetrize adjacency matrix
        adj = tf.nn.sigmoid(adj)
        adj = tf.cast(adj > 0.5, tf.float32)  # Binarize adjacency matrix

        valid_atom_types = tf.constant([1, 6, 7, 8, 9], dtype=tf.int64)
        
        node_features = tf.reshape(node_feature_flat, (batch_size, self.num_nodes, self.node_features))
        node_features = tf.nn.softmax(node_features, axis=-1)
        node_features = tf.clip_by_value(node_features, 0, len(valid_atom_types) - 1)
        node_features = tf.cast(node_features, tf.int32)
        node_features = tf.gather(valid_atom_types, node_features)
        node_features = tf.cast(node_features, tf.float32)

        return adj, node_features
    
    def compute_molecular_properties(self, adj):
        return tf.reduce_sum(adj, axis=[1, 2]) / self.num_nodes

    def loss_function(self, real_output, fake_output, real_props, fake_props):
        loss_func = tf.keras.losses.BinaryCrossentropy(from_logits=False)
        mse_loss = tf.keras.losses.MeanSquaredError()

        gen_loss = loss_func(tf.ones_like(fake_output), fake_output)
        disc_loss = loss_func(tf.ones_like(real_output), real_output) + loss_func(tf.zeros_like(fake_output), fake_output)

        prop_loss = mse_loss(real_props, fake_props)  # Corrected to use fake_props

        return gen_loss, disc_loss, prop_loss

    def fit(self, dataset, discriminator, compute_molecular_properties, epochs=10, lambda_prop=0.1):
        d_loss_list = []
        g_loss_list = []

        for epoch in range(epochs):
            for batch_idx, (real_node_features, real_adj, real_properties) in enumerate(dataset):
                batch_size = tf.shape(real_node_features)[0]
                z = tf.random.normal([batch_size, self.latent_dim])

                gen_adj, gen_node_features = self(z, real_properties)
                fake_props = compute_molecular_properties(gen_adj, gen_node_features)  # Ensure property computation

                with tf.GradientTape() as tape:
                    fake_output = discriminator(gen_adj, gen_node_features, real_properties)
                    real_output = discriminator(real_adj, real_node_features, real_properties)

                    gen_loss, disc_loss, prop_loss = self.loss_function(real_output, fake_output, real_properties, fake_props)

                    lambda_gp = 10  # Weight for gradient penalty
                    gradients = tape.gradient(disc_loss, discriminator.mlp.trainable_variables)
                    gradient_penalty = lambda_gp * tf.reduce_mean((tf.norm(gradients, axis=1) - 1.0) ** 2)
                    disc_loss += gradient_penalty  # Stabilize training

                    d_loss_list.append(disc_loss.numpy())
                    g_loss_list.append(gen_loss.numpy())

                discriminator.optimizer.apply_gradients(zip(gradients, discriminator.mlp.trainable_variables))

                for _ in range(2):  # Update generator more frequently
                    z = tf.random.normal([batch_size, self.latent_dim])

                    with tf.GradientTape() as tape:
                        gen_adj, gen_node_features = self(z, real_properties)
                        fake_output = discriminator(gen_adj, gen_node_features, real_properties)
                        fake_props = compute_molecular_properties(gen_adj, gen_node_features)

                        g_loss, _, prop_loss = self.loss_function(real_output, fake_output, real_properties, fake_props)
                        g_loss += lambda_prop * prop_loss

                    gradients = tape.gradient(g_loss, self.mlp.trainable_variables)
                    self.optimizer.apply_gradients(zip(gradients, self.mlp.trainable_variables))

                if batch_idx % 10 == 0:
                    print(f"Epoch {epoch+1}/{epochs}, Batch {batch_idx}, "
                          f"D Loss: {disc_loss.numpy():.4f}, G Loss: {g_loss.numpy():.4f}, Prop Loss: {prop_loss.numpy():.4f}")

        return d_loss_list, g_loss_list"""

# %%
class GraphGenerator(tf.keras.Model):
    def __init__(self, num_nodes, node_features, latent_dim, num_prop):
        super().__init__()
        self.num_nodes = num_nodes
        self.node_features = node_features
        self.latent_dim = latent_dim
        self.num_prop = num_prop

        self.mlp = models.Sequential([
            layers.Dense(128, input_shape=(self.latent_dim + self.num_prop,), activation="relu"),
            layers.Dense(256, activation="relu"),
            layers.Dense((self.num_nodes * self.num_nodes) + (self.num_nodes * self.node_features), activation="softmax")
        ])

        self.optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5)

    def call(self, z, properties):
        batch_size = tf.shape(z)[0]
        output = self.mlp(tf.concat([z, properties], axis=-1))  

        adj_flat = output[:, :self.num_nodes * self.num_nodes]
        adj_flat = tf.nn.sigmoid(adj_flat)
        node_feature_flat = output[:, self.num_nodes * self.num_nodes:]

        adj = tf.reshape(adj_flat, (batch_size, self.num_nodes, self.num_nodes))
        adj = (adj + tf.transpose(adj, perm=[0, 2, 1])) / 2  
        adj = tf.nn.sigmoid(adj)
        adj = tf.cast(adj > 0.5, tf.float32)  

        valid_atom_types = tf.constant([1, 6, 7, 8, 9], dtype=tf.int64)
        
        node_features = tf.reshape(node_feature_flat, (batch_size, self.num_nodes, self.node_features))
        node_features = tf.nn.softmax(node_features, axis=-1)
        node_features = tf.clip_by_value(node_features, 0, len(valid_atom_types) - 1)
        node_features = tf.cast(node_features, tf.int32)
        node_features = tf.gather(valid_atom_types, node_features)
        node_features = tf.cast(node_features, tf.float32)

        return adj, node_features
    
    def compute_molecular_properties(self, adj):
        prop = tf.reduce_sum(adj, axis=[1, 2]) / self.num_nodes
        prop = tf.expand_dims(prop, axis=-1)  
        return tf.tile(prop, [1, self.num_prop])  


    def loss_function(self, real_output, fake_output, real_props, fake_props):
        loss_func = tf.keras.losses.BinaryCrossentropy(from_logits=False)
        mse_loss = tf.keras.losses.MeanSquaredError()

        gen_loss = loss_func(tf.ones_like(fake_output), fake_output)
        disc_loss = loss_func(tf.ones_like(real_output), real_output) + loss_func(tf.zeros_like(fake_output), fake_output)

        prop_loss = mse_loss(real_props, fake_props)

        return gen_loss, disc_loss, prop_loss

    def fit(self, dataset, discriminator, epochs=10, lambda_prop=0.1):
        d_loss_list = []
        g_loss_list = []

        for epoch in range(epochs):
            for batch_idx, (real_node_features, real_adj, real_properties) in enumerate(dataset):
                batch_size = tf.shape(real_node_features)[0]
                z = tf.random.normal([batch_size, self.latent_dim])

                gen_adj, gen_node_features = self(z, real_properties)
                fake_props = self.compute_molecular_properties(gen_adj)  # <-- Called directly

                with tf.GradientTape() as tape:
                    fake_output = discriminator(gen_adj, gen_node_features, real_properties)
                    real_output = discriminator(real_adj, real_node_features, real_properties)

                    gen_loss, disc_loss, prop_loss = self.loss_function(real_output, fake_output, real_properties, fake_props)

                    lambda_gp = 10  # Weight for gradient penalty
                    gradients = tape.gradient(disc_loss, discriminator.mlp.trainable_variables)
                    gradient_penalty = lambda_gp * tf.reduce_mean((tf.norm(gradients, axis=1) - 1.0) ** 2)
                    disc_loss += gradient_penalty  # Stabilize training

                    d_loss_list.append(disc_loss.numpy())
                    g_loss_list.append(gen_loss.numpy())

                discriminator.optimizer.apply_gradients(zip(gradients, discriminator.mlp.trainable_variables))

                for _ in range(2):  # Update generator more frequently
                    z = tf.random.normal([batch_size, self.latent_dim])

                    with tf.GradientTape() as tape:
                        gen_adj, gen_node_features = self(z, real_properties)
                        fake_output = discriminator(gen_adj, gen_node_features, real_properties)
                        fake_props = self.compute_molecular_properties(gen_adj)  # <-- Called directly

                        g_loss, _, prop_loss = self.loss_function(real_output, fake_output, real_properties, fake_props)
                        g_loss += lambda_prop * prop_loss

                    gradients = tape.gradient(g_loss, self.mlp.trainable_variables)
                    self.optimizer.apply_gradients(zip(gradients, self.mlp.trainable_variables))

                if batch_idx % 10 == 0:
                    print(f"Epoch {epoch+1}/{epochs}, Batch {batch_idx}, "
                          f"D Loss: {disc_loss.numpy():.4f}, G Loss: {g_loss.numpy():.4f}, Prop Loss: {prop_loss.numpy():.4f}")

        return d_loss_list, g_loss_list

# %%
class GraphDiscriminator(tf.keras.Model):
    def __init__(self, num_nodes, node_features, num_prop):
        super().__init__()
        self.input_dim = num_nodes * num_nodes
        self.condition_dim = num_nodes * node_features
        self.property_dim = num_prop

        self.mlp = models.Sequential([
            layers.Dense(256, input_shape=(self.input_dim + self.condition_dim + self.property_dim,), activation=tf.nn.leaky_relu),
            layers.Dense(128, activation=tf.nn.leaky_relu),
            layers.BatchNormalization(),
            layers.Dense(1, activation='sigmoid')
        ])

        self.optimizer = tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.5)

    def call(self, adj, node_features, properties):
        batch_size = tf.shape(adj)[0]

        adj_flat = tf.reshape(adj, (batch_size, self.input_dim))
        node_features_flat = tf.reshape(node_features, (batch_size, self.condition_dim))

        properties = tf.reshape(properties, (batch_size, self.property_dim))

        combined = tf.concat([adj_flat, node_features_flat, properties], axis=1)

        validity = self.mlp(combined)
        return validity

# %%
# %run ../PyFiles/HierarchicalDiscriminator.py

# %%
def adjacency_matrix_to_mol(inp_matrix):
  mol = Chem.RWMol()
  atom_types = np.unique(inp_matrix[1])
  matrix = inp_matrix[0]
  atom_map = {i: mol.AddAtom(Chem.Atom(int(atom_types[i]))) for i in range(len(atom_types))}

  if isinstance(matrix, tf.Tensor):
        matrix = matrix.numpy()
  if isinstance(atom_types, tf.Tensor):
      atom_types = atom_types.numpy()

  matrix = np.array(matrix)
  atom_types = np.array(atom_types)

  if len(matrix) != len(atom_types):
    raise ValueError("NUMBER OF ATOM TYPES DOES NOT MATCH MATRIX DIMENSIONS")

  # Step 1: Add Atoms
  for i, atom_num in enumerate(atom_types):
    atom = Chem.Atom(int(atom_num))
    mol_idx = mol.AddAtom(atom)
    atom_map[i] = mol_idx

  # Step 2: Add Bonds
  for i in range(len(matrix)):
    for j in range(i + 1, len(matrix)):
        if j not in atom_map:
            continue

        value = int(np.argmax(matrix[i, j]))
        value = min(max(value, 0), 4)

        if value != 0:
            bond_type = {
                1: Chem.BondType.SINGLE,
                2: Chem.BondType.DOUBLE,
                3: Chem.BondType.TRIPLE,
                4: Chem.BondType.AROMATIC
            }.get(value, None)

            if bond_type is None:
                raise ValueError(f"INVALID BOND TYPE DETECTED: {value}")

            print(f"Adding bond: {i}-{j} Type: {bond_type}")
            mol.AddBond(atom_map[i], atom_map[j], bond_type)

  return mol

# %%
#discriminator = HierarchicalDiscriminator(num_nodes=max_size, node_features=num_features)

# %%
generator = GraphGenerator(num_nodes=max_size, node_features=num_features, latent_dim=128, num_prop=num_prop)
discriminator = GraphDiscriminator(num_nodes=max_size, node_features=num_features, num_prop=num_prop)

d_loss, g_loss = generator.fit(dataset_small, discriminator, epochs=10)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[57], line 4
#       1 generator = GraphGenerator(num_nodes=max_size, node_features=num_features, latent_dim=128, num_prop=num_prop)
#       2 discriminator = GraphDiscriminator(num_nodes=max_size, node_features=num_features, num_prop=num_prop)
# ----> 4 d_loss, g_loss = generator.fit(dataset_small, discriminator, epochs=10)
#
# Cell In[54], line 78, in GraphGenerator.fit(self, dataset, discriminator, epochs, lambda_prop)
#      76 lambda_gp = 10  # Weight for gradient penalty
#      77 gradients = tape.gradient(disc_loss, discriminator.mlp.trainable_variables)
# ---> 78 gradient_penalty = lambda_gp * tf.reduce_mean((tf.norm(gradients, axis=1) - 1.0) ** 2)
#      79 disc_loss += gradient_penalty  # Stabilize training
#      81 d_loss_list.append(disc_loss.numpy())
#
# ...

# %%
"""generator = GraphGenerator(num_nodes=max_size, node_features=num_features, latent_dim=128, num_prop=num_prop)
discriminator = GraphDiscriminator(num_nodes=max_size, node_features=num_features, num_prop=num_prop)

d_loss, g_loss = generator.fit(dataset_small, discriminator, epochs=10)"""
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[40], line 4
#       1 generator = GraphGenerator(num_nodes=max_size, node_features=num_features, latent_dim=128, num_prop=num_prop)
#       2 discriminator = GraphDiscriminator(num_nodes=max_size, node_features=num_features, num_prop=num_prop)
# ----> 4 d_loss, g_loss = generator.fit(dataset_small, discriminator, epochs=10)
#
# Cell In[39], line 65, in GraphGenerator.fit(self, dataset, discriminator, epochs, lambda_prop)
#      62 gen_adj, gen_node_features = self(z, real_properties)
#      63 fake_props = self.compute_molecular_properties(gen_adj)
# ---> 65 fake_output = discriminator(gen_adj, gen_node_features, real_properties)
#      66 real_output = discriminator(real_adj, real_node_features, real_properties)
# ...

# %%
plt.figure(figsize=(8, 6)) 
plt.plot(d_loss, label="Discriminator Loss", color="blue", linewidth=2)  
plt.plot(g_loss, label="Generator Loss", color="orange", linewidth=2)  

plt.xlabel("Iterations", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.title("Generator and Discriminator Loss Over Time", fontsize=14)
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6) 

plt.show()

# %% [markdown]
# ### Notes
#     smoothing reduced the high generator loss and made the discriminator loss not go as low
#
#     random flipping of the labels cuased the spikes in loss for the discriminator and made the generator stagnat and not go as high
